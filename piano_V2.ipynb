# %%
from scipy.io.wavfile import read, write
import numpy as np
import matplotlib.pyplot as plt

# %%
# !pip install scikit-image

# %%
sample_rate, piano = read('piano1h.wav');
piano = piano[15000:-15000]
print(sample_rate)
sample_rate, back = read('back20m.wav');
back = back[150000:-15000]
print(sample_rate)
c = piano[0:300000] + back[0:300000]
write('piano+back.wav', sample_rate, c)
# n = len(a)
# print(a.dtype)
# b = np.mean(b, axis=1)
# Out:
# 48000
# 48000
# C:\Users\MOSES\anaconda3\envs\tf230\lib\site-packages\ipykernel_launcher.py:1: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   """Entry point for launching an IPython kernel.
# C:\Users\MOSES\anaconda3\envs\tf230\lib\site-packages\ipykernel_launcher.py:4: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   after removing the cwd from sys.path.

# %%
plt.plot(piano[0:20000]);

# %%
plt.plot(back[0:20000]);

# %%
from skimage import util

M = 2**10ACZSzm''76mjjttttttttttttttt/

piano_slices = util.view_as_windows(piano, window_shape=(M,), step=128)[0:800000]
print(f'Audio shape: {piano.shape}, Sliced audio shape: {piano_slices.shape}')

back_slices = util.view_as_windows(back, window_shape=(M,), step=2**6)[0:800000]
print(f'Audio shape: {back.shape}, Sliced audio shape: {back_slices.shape}')
# Out:
# Audio shape: (174904945,), Sliced audio shape: (800000, 1024)
# Audio shape: (56323432,), Sliced audio shape: (800000, 1024)

# %%
input_data = piano_slices + back_slices
output_data = piano_slices


x_train = input_data[0:500000]
x_valid = input_data[500000:]

y_train = output_data[0:500000]
y_valid = output_data[500000:]

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Input, Flatten, Reshape,  concatenate, Average
from tensorflow.keras.layers import Conv1D, Conv1DTranspose, Add
from tensorflow.keras.models import Model # to create NN model
from tensorflow.keras.utils import plot_model # to plot model
from tensorflow.keras.utils import Sequence # to create genertor
# Check tensorflow version.
print(tf.__version__)
# Set the project directory where unzip folder of datasets is located.
# Out:
# 2.3.0

# %%
kernel_size = 3
n_filters = 64
inp = Input(shape=(M,1))
c1 = Conv1D(filters=n_filters, kernel_size=kernel_size, padding = 'same', name='c1')(inp)
# c2 = Conv1D(filters=n_filters, kernel_size=kernel_size, padding = 'same', name='c2')(c1)
print(c2.shape)
# c3 = Conv1D(filters=n_filters, kernel_size=kernel_size, padding = 'same', name='c3')(c2)
# c4 = Conv1D(filters=n_filters, kernel_size=kernel_size, padding = 'same', name='c4')(c3)
# # print(c4.shape)
# c5 = Conv1D(filters=n_filters, kernel_size=kernel_size, padding = 'same', name='c5')(c4)
# c6 = Conv1D(filters=n_filters, kernel_size=kernel_size, padding = 'same', name='c6')(c5)
# # print(c6.shape)
# c7 = Conv1D(filters=n_filters, kernel_size=kernel_size, padding = 'same', name='c7')(c6)
# c8 = Conv1D(filters=n_filters, kernel_size=kernel_size, padding = 'same', name='c8')(c7)
# # print(c8.shape)
# c9 = Conv1D(filters=n_filters, kernel_size=kernel_size, padding = 'same', name='c9')(c8)
# c10 = Conv1D(filters=n_filters, kernel_size=kernel_size, padding = 'same', name='c10')(c9)
# # print(c10.shape)
# c11 = Conv1D(filters=n_filters, kernel_size=kernel_size, padding = 'same', name='c11')(c10)
# c12 = Conv1D(filters=n_filters, kernel_size=kernel_size, padding = 'same', name='c12')(c11)
# # print(c12.shape)
# c13 = Conv1D(filters=n_filters, kernel_size=kernel_size, padding = 'same', name='c13')(c12)
# c14 = Conv1D(filters=n_filters, kernel_size=kernel_size, padding = 'same', name='c14')(c13)
# # print(c14.shape)


# d1 = Conv1DTranspose(n_filters, kernel_size=kernel_size, padding = 'same', name = 'd1')(c14)
# d2 = Conv1DTranspose(n_filters, kernel_size=kernel_size, padding = 'same', name = 'd2')(d1)
# # print(d2.shape)
# add1 = Average()([d2, c12])
# # add1 = Add()([d2, c12])
# # print(add1.shape)
# rl1 = tf.keras.layers.ReLU(1)(add1)
# d3 = Conv1DTranspose(n_filters, kernel_size=kernel_size,  padding = 'same', name = 'd3')(rl1)
# d4 = Conv1DTranspose(n_filters, kernel_size=kernel_size,  padding = 'same', name = 'd4')(d3)
# # print(d4.shape)
# add2 = Average()([d4, c10])
# # add2 = Add()([d4, c10])
# # print(add2.shape)
# rl2 = tf.keras.layers.ReLU(1)(add2)

# d5 = Conv1DTranspose(n_filters, kernel_size=kernel_size,  padding = 'same', name = 'd5')(rl2)
# d6 = Conv1DTranspose(n_filters, kernel_size=kernel_size,  padding = 'same', name = 'd6')(d5)
# # print(d6.shape)
# add3 = Average()([d6, c8])
# # add3 = Add()([d6, c8])
# # print(add3.shape)
# rl3 = tf.keras.layers.ReLU(1)(add3)

# d7 = Conv1DTranspose(n_filters, kernel_size=kernel_size,  padding = 'same', name = 'd7')(rl3)
# d8 = Conv1DTranspose(n_filters, kernel_size=kernel_size,  padding = 'same', name = 'd8')(d7)
# # print(d8.shape)
# add4 = Average()([d8, c6])
# # add4 = Add()([d8, c6])
# # print(add4.shape)
# rl4 = tf.keras.layers.ReLU(1)(add4)

# d9 = Conv1DTranspose(n_filters, kernel_size=kernel_size,  padding = 'same', name = 'd9')(rl4)
# d10 = Conv1DTranspose(n_filters, kernel_size=kernel_size,  padding = 'same', name = 'd10')(d9)
# # print(d10.shape)
# add5 = Average()([d10, c4])
# # add5 = Add()([d10, c4])
# # print(add5.shape)
# rl5 = tf.keras.layers.ReLU(1)(add5)

# d11 = Conv1DTranspose(n_filters, kernel_size=kernel_size,  padding = 'same', name = 'd11')(rl5)
# d12 = Conv1DTranspose(n_filters, kernel_size=kernel_size,  padding = 'same', name = 'd12')(d11)
# # print(d12.shape)
# add6 = Average()([d12, c2])
# # add6 = Add()([d12, c2])
# # print(add6.shape)
# rl6 = tf.keras.layers.ReLU(1)(add6)

# d13 = Conv1DTranspose(n_filters, kernel_size=kernel_size,  padding = 'same', name = 'd13')(rl6)
# d14 = Conv1DTranspose(3, kernel_size=kernel_size,  padding = 'same', name = 'd14')(d13)
# # print(d14.shape)
# add7 = Average()([d14, inp])
# # add7 = Add()([d14, inp])
# # print(add7.shape)
# rl7 = tf.keras.layers.ReLU(1)(add7)

# model_red30 = Model(inputs = inp, outputs = rl7)

# %%
plot_model(model_red30)

# %%
print(model_red30.summary())
